# %% [markdown]
# ## Introduction to Matplotlib

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4])

# %%
plt.show()

# %%
x = [2,2,3,2]
y= [11, 22,33,44]
plt.plot(x,y)
plt.show()

# %%
fig = plt.figure() # creates a figure
ax = fig.add_subplot() #adds axes
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,[50,100,200,500]);

# %%
plt.show()

# %%
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %%
x = [1,2,3,4]
y = [11, 22, 33, 44]
fig, ax =plt.subplots(figsize=(10,10))
ax.plot(x,y)
ax.set(title="Simple plot", xlabel="x-axis", ylabel="y-axis")
fig.savefig("images/sample-plot.png")

# %%
plt.show()

# %% [markdown]
# ## Figures with NumPy arrays

# %%
x = np.linspace(0,10,100)
x [:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
x[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
fig, ax =plt.subplots()
ax.plot(x, x**2) # line plot
plt.show()

# %%
#Scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
plt.show()

# %%
fig, ax =plt.subplots()
ax.scatter(x, np.sin(x))

# %%
plt.show()

# %%
# Plot from dictionary
nut_butter_prices = { "Almond butter" : 10,
                     "Peanut_butter" : 8,
                     "Cashew butter" : 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Nut Butter store", ylabel= "Prices ($)")
# Out:
# [Text(0.5, 1.0, 'Nut Butter store'), Text(0, 0.5, 'Prices ($)')]

# %%
plt.show()

# %%
fig, ax =plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
plt.show()

# %%
x = np.random.randn(1000)
fig, ax =plt.subplots()
ax.hist(x)
plt.show()

# %%
plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(10,5))
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
plt.show()

# %%
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10,5))
ax[0,0].plot(x, x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10))
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000))
plt.show()

# %%
car_sales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 car_sales
#
# NameError: name 'car_sales' is not defined

# %%
car_sales = pd.read_csv("car_sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index = pd.date_range("1/1/2024", periods=1000))
ts = ts.cumsum()
ts.plot()
plt.show()

# %%
car_sales["Price"] = np.array([4000, 5000, 7000, 22000, 3500, 4500, 7500, 7000, 6250, 9700])

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2024", periods=len(car_sales))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2024-01-01
# 1   Honda    Red          87899      4   5000 2024-01-02
# 2  Toyota   Blue          32549      3   7000 2024-01-03
# 3     BMW  Black          11179      5  22000 2024-01-04
# 4  Nissan  White         213095      4   3500 2024-01-05
# 5  Toyota  Green          99213      4   4500 2024-01-06
# 6   Honda   Blue          45698      4   7500 2024-01-07
# 7   Honda   Blue          54738      4   7000 2024-01-08
# 8  Toyota  White          60000      4   6250 2024-01-09
# 9  Nissan  White          31600      4   9700 2024-01-10

# %%
car_sales["Total sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500
# 5  Toyota  Green          99213      4   4500 2024-01-06        46000
# 6   Honda   Blue          45698      4   7500 2024-01-07        53500
# 7   Honda   Blue          54738      4   7000 2024-01-08        60500
# 8  Toyota  White          60000      4   6250 2024-01-09        66750
# 9  Nissan  White          31600      4   9700 2024-01-10        76450

# %%
car_sales.plot(x="Sale Date", y="Total sales") ;

# %%
plt.show()

# %%
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.show()

# %%
x = np.random.randn(10,4)
x
# Out:
# array([[ 0.468294  , -0.72704847, -0.10218134,  0.70526582],
#        [-0.14907356, -1.51439719,  1.40889001,  0.25326671],
#        [-1.16333181,  0.82959471, -0.8343298 ,  0.21243272],
#        [ 0.49771484,  0.69670508,  0.38127344,  0.03143205],
#        [-0.74944682,  1.0019068 ,  0.50172402,  1.80985771],
#        [-1.50957536, -0.05666571, -0.00756781,  0.11356239],
#        [ 0.46045559, -1.21928404,  0.44913834, -0.43619021],
#        [ 1.66577235,  0.52735491,  1.22432423, -2.01500825],
#        [ 1.53786412,  0.50380238, -0.53614038, -1.36163536],
#        [-0.09156253,  1.1826998 , -1.74045488, -1.46896417]])

# %%
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])

# %%
df
# Out:
#           a         b         c         d
# 0  0.591741  0.633129 -0.704546  0.047634
# 1  1.007259 -0.552765  0.315257  1.297989
# 2  0.219844 -2.334976  1.727094  0.886447
# 3 -0.341288  0.435528 -0.935077 -0.108129
# 4 -0.902936 -0.355228  0.208165 -1.240968
# 5  0.351003 -1.520078  0.263653  0.637381
# 6  0.999829 -0.113661 -0.966923  1.430514
# 7 -2.257911  0.281820 -0.485015 -0.453913
# 8 -0.114136 -0.942494  1.110758 -2.583061
# 9  0.029422  0.090601 -2.759237  1.000065

# %%
df.plot.bar();

# %%
plt.show()

# %%
df.plot(kind="bar");
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500
# 5  Toyota  Green          99213      4   4500 2024-01-06        46000
# 6   Honda   Blue          45698      4   7500 2024-01-07        53500
# 7   Honda   Blue          54738      4   7000 2024-01-08        60500
# 8  Toyota  White          60000      4   6250 2024-01-09        66750
# 9  Nissan  White          31600      4   9700 2024-01-10        76450

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");
plt.show()

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
plt.show()

# %%
car_sales["Odometer (KM)"].plot(kind="hist");
plt.show()

# %%
car_sales["Odometer (KM)"].plot.hist(bins=30);
plt.show()

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=10);
plt.show()

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True);
plt.show()

# %%
over_50 = heart_disease[heart_disease["age"] > 50]

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
len(over_50)
# Out:
# 208

# %%
# Pyplot
over_50.plot(kind="scatter",
             x="age",
             y="chol",
             c="target");
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
             x="age",
             y="chol",
             c="target",
             ax=ax);
ax.set_xlim([45, 80])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

scatter = ax.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"]);
ax.set(title="Heart Disease and Cholestrol levels",
       xlabel="Age",
       ylabel="cholestrol")

ax.legend(*scatter.legend_elements(), title="Target");
ax.axhline(over_50["chol"].mean(),
           linestyle="--")
plt.show()

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10,10),
                              sharex=True);
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50['target']);

ax0.set(title="Heart disease and cholestrol levels",
        # xlabel="Age",
        ylabel="Cholestrol")
ax0.legend(*scatter.legend_elements(), title="target")
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--");

scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50['target']);
ax1.set(title="Heart disease and Max heartrate",
        xlabel="Age",
        ylabel="Max heart rate")
ax1.legend(*scatter.legend_elements(), title="target")
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle="--");
fig.suptitle("Heart Disease Analysis",
             fontsize=16,
             fontweight="bold")
plt.show()

# %%
# subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10,10),
                              sharex=True);
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50['target']);

ax0.set(title="Heart disease and cholestrol levels",
        # xlabel="Age",
        ylabel="Cholestrol")
ax0.legend(*scatter.legend_elements(), title="target")
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--");

scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50['target']);
ax1.set(title="Heart disease and Max heartrate",
        xlabel="Age",
        ylabel="Max heart rate")
ax1.legend(*scatter.legend_elements(), title="target")
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle="--");
fig.suptitle("Heart Disease Analysis",
             fontsize=16,
             fontweight="bold")
plt.show()

# %%
## Styling

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();
plt.show()

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
car_sales["Price"].plot();
plt.show()

# %%
plt.style.use('dark_background')
car_sales["Price"].plot();
plt.show()

# %%
x = np.random.randn(10,4)
x
# Out:
# array([[-0.66971307,  0.48006996, -0.87777144, -1.94804243],
#        [-1.0551897 ,  0.75129785, -0.73585991, -1.3070668 ],
#        [-0.93868727, -1.21439969, -0.75985005,  1.19867822],
#        [ 0.40991655,  0.31686038, -0.28021676,  0.3122165 ],
#        [ 2.06914161, -0.49589076, -1.70563555,  0.09883577],
#        [-0.1150408 , -1.33106416,  1.6073076 ,  0.53586878],
#        [-0.12920029, -1.46664763, -1.62765598,  0.15885587],
#        [-0.07735909, -1.71230874, -0.56196436,  0.5159551 ],
#        [-0.19388045,  0.45795121, -0.86439756, -0.25181636],
#        [ 0.09408844, -0.64625461,  0.17551445,  0.09503291]])

# %%
df = pd.DataFrame(x, columns= ("a", "b","c", "d"))

# %%
df
# Out:
#           a         b         c         d
# 0 -0.669713  0.480070 -0.877771 -1.948042
# 1 -1.055190  0.751298 -0.735860 -1.307067
# 2 -0.938687 -1.214400 -0.759850  1.198678
# 3  0.409917  0.316860 -0.280217  0.312216
# 4  2.069142 -0.495891 -1.705636  0.098836
# 5 -0.115041 -1.331064  1.607308  0.535869
# 6 -0.129200 -1.466648 -1.627656  0.158856
# 7 -0.077359 -1.712309 -0.561964  0.515955
# 8 -0.193880  0.457951 -0.864398 -0.251816
# 9  0.094088 -0.646255  0.175514  0.095033

# %%
ax = df.plot(kind="bar")
type(ax)
ax.set(title="Random Bargraph",
       xlabel="Row number",
       ylabel="random number")
ax.legend().set_visible(True)

plt.show()

# %%
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots(figsize=(10,6))

scatter = ax.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap="winter");
ax.set(title="Heart Disease and Cholestrol levels",
       xlabel="Age",
       ylabel="cholestrol")

ax.legend(*scatter.legend_elements(), title="Target");
ax.axhline(over_50["chol"].mean(),
           linestyle="--")
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10,10),
                              sharex=True);
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50['target'],
                      cmap="winter");

ax0.set(title="Heart disease and cholestrol levels",
        # xlabel="Age",
        ylabel="Cholestrol")
ax0.set_xlim(50,80)
ax0.legend(*scatter.legend_elements(), title="target")
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--");

scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50['target'],
                      cmap="winter");
ax1.set(title="Heart disease and Max heartrate",
        xlabel="Age",
        ylabel="Max heart rate")
ax1.legend(*scatter.legend_elements(), title="target")
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle="--");
fig.suptitle("Heart Disease Analysis",
             fontsize=16,
             fontweight="bold")
plt.show()
